# %% [markdown]
# ## importing the necessary libraries

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ##### importing the datasets

# %%
flipkart1 = pd.read_csv('flipkart_com-ecommerce_sample.csv')
flipkart1.head()
# Out:
#                     flipkartuniq_id    flipkartcrawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                  flipkartproduct_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                     flipkartproduct_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                        flipkartproduct_category_tree       flipkartpid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    flipkartretail_price  flipkartdiscounted_price  \
# 0                 999.0                     379.0
# 1               32157.0                   22646.0
# 2                 999.0                     499.0
# 3                 699.0                     267.0
# 4                 220.0                     210.0
#
#                                        flipkartimage  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...
#
#    flipkartis_FK_Advantage_product  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#                                  flipkartdescription flipkartproduct_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...    No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...    No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...    No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...    No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...    No rating available
#
#   flipkartoverall_rating flipkartbrand  \
# 0    No rating available        Alisha
# 1    No rating available  FabHomeDecor
# 2    No rating available            AW
# 3    No rating available        Alisha
# 4    No rating available        Sicons
#
#                       flipkartproduct_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
amazon1 = pd.read_csv('amz_com-ecommerce_sample.csv', encoding= 'unicode_escape')
amazon1.head()
# Out:
#                       amazonuniq_id      amazoncrawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                    amazonproduct_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                       amazonproduct_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                          amazonproduct_category_tree         amazonpid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    amazonretail_price  amazondiscounted_price  \
# 0                 982                     438
# 1               32143                   29121
# 2                 991                     551
# 3                 694                     325
# 4                 208                     258
#
#                                          amazonimage  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...
#
#    amazonis_FK_Advantage_product  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#                                    amazondescription amazonproduct_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...  No rating available
#
#   amazonoverall_rating   amazonbrand  \
# 0  No rating available        Alisha
# 1  No rating available  FabHomeDecor
# 2  No rating available            AW
# 3  No rating available        Alisha
# 4  No rating available        Sicons
#
#                         amazonproduct_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %% [markdown]
# ## Data Preprocessing
# ###### Now, we categorize the features depending on their datatype (int, float, object) and then calculate the number of them.

# %%
#checking the shape of dataset.
f = flipkart1.shape
a = amazon1.shape
print('Shape of flipkart dataset : ', f)
print('Shape of amoazon dataset : ', a)
# Out:
# Shape of flipkart dataset :  (20000, 15)
# Shape of amoazon dataset :  (20000, 15)

# %%
flipkart1.columns
# Out:
# Index(['flipkartuniq_id', 'flipkartcrawl_timestamp', 'flipkartproduct_url',
#        'flipkartproduct_name', 'flipkartproduct_category_tree', 'flipkartpid',
#        'flipkartretail_price', 'flipkartdiscounted_price', 'flipkartimage',
#        'flipkartis_FK_Advantage_product', 'flipkartdescription',
#        'flipkartproduct_rating', 'flipkartoverall_rating', 'flipkartbrand',
#        'flipkartproduct_specifications'],
#       dtype='object')

# %%
amazon1.columns
# Out:
# Index(['amazonuniq_id', 'amazoncrawl_timestamp', 'amazonproduct_url',
#        'amazonproduct_name', 'amazonproduct_category_tree', 'amazonpid',
#        'amazonretail_price', 'amazondiscounted_price', 'amazonimage',
#        'amazonis_FK_Advantage_product', 'amazondescription',
#        'amazonproduct_rating', 'amazonoverall_rating', 'amazonbrand',
#        'amazonproduct_specifications'],
#       dtype='object')

# %%
obj = (flipkart1.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables for flipkart dataset:",len(object_cols))

obj = (amazon1.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables for amazon dataset:",len(object_cols))
# Out:
# Categorical variables for flipkart dataset: 12
# Categorical variables for amazon dataset: 12

# %%
int_ = (flipkart1.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables for flipkart dataset:",len(num_cols))

int_ = (amazon1.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables for amazon dataset:",len(num_cols))
# Out:
# Integer variables for flipkart dataset: 0
# Integer variables for amazon dataset: 0

# %%
fl = (flipkart1.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables for flipkart dataset:",len(fl_cols))

fl = (amazon1.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables for amazon dataset:",len(fl_cols))
# Out:
# Float variables for flipkart dataset: 2
# Float variables for amazon dataset: 0

# %% [markdown]
# ## Data Cleaning

# %%
flipkart1.drop(['flipkartcrawl_timestamp', 
              'flipkartproduct_url', 
              'flipkartproduct_category_tree', 
              'flipkartpid',
              'flipkartimage',
              'flipkartis_FK_Advantage_product',
              'flipkartoverall_rating',
              'flipkartproduct_specifications'
             ], axis=1, inplace=True)

amazon1.drop(['amazoncrawl_timestamp', 
              'amazonproduct_url', 
              'amazonproduct_category_tree', 
              'amazonpid',
              'amazonimage',
              'amazonis_FK_Advantage_product',
              'amazonoverall_rating',
              'amazonproduct_specifications'
             ], axis=1, inplace=True)

# %%
flipkart = flipkart1.dropna()
amazon = amazon1.dropna()

# %%
flipkart.isnull().sum()
# Out:
# flipkartuniq_id             0
# flipkartproduct_name        0
# flipkartretail_price        0
# flipkartdiscounted_price    0
# flipkartdescription         0
# flipkartproduct_rating      0
# flipkartbrand               0
# dtype: int64

# %%
amazon.isnull().sum()
# Out:
# amazonuniq_id             0
# amazonproduct_name        0
# amazonretail_price        0
# amazondiscounted_price    0
# amazondescription         0
# amazonproduct_rating      0
# amazonbrand               0
# dtype: int64

# %% [markdown]
# #### so both dataset is clean now and ready to process further.

# %%
# dropping the outliers.

wild_card = flipkart[flipkart.flipkartdiscounted_price > 1000].index

flipkart = flipkart.drop(wild_card)
amazon = amazon.drop(wild_card)

# %%
plt.figure(figsize=(10, 6))
sns.distplot(flipkart.flipkartdiscounted_price, color='red', label="Flipkart", kde=False, bins=30)
sns.distplot(amazon.amazondiscounted_price, color='green', label="Amazon", kde=False, bins=30)
plt.legend()
plt.xlabel('Price')
plt.ylabel('Products')
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Merging the tables of amazon and flipkart

# %%
flipkart.columns = ['uniq_id','flipkartproduct_name','flipkartretail_price','flipkartdiscounted_price','flipkartdescription','flipkartoverall_rating','flipkartbrand']

amazon.columns = ['uniq_id','amazonproduct_name','amazonretail_price','amazondiscounted_price','amazondescription','amazonoverall_rating','amazonbrand']

df = pd.merge(flipkart, amazon, how='outer')
df = df.drop_duplicates()

# %%
df
# Out:
#                                 uniq_id  \
# 0      c2d766ca982eca8304150849735ffef9
# 1      f449ec65dcbc041b6ae5e6a32717d01b
# 2      0973b37acd0c664e3de26e97e5571454
# 3      bc940ea42ee6bef5ac7cea3fb5cfbee7
# 4      c2a17313954882c1dba461863e98adf2
# ...                                 ...
# 10133  776ecca7b6f0584b1dffaeb4635b385a
# 10134  0fb87924d87d95d0a92b476c39fe6776
# 10135  a5590a2bfaddd4c4c9e9b6bf6409a464
# 10136  43fbafdae704714c6543690161d3adb1
# 10137  9d37d5a4ce327fb84cec4f56a2f0ac38
#
#                                     flipkartproduct_name  \
# 0                    Alisha Solid Women's Cycling Shorts
# 1                                             AW Bellies
# 2                    Alisha Solid Women's Cycling Shorts
# 3                  Sicons All Purpose Arnica Dog Shampoo
# 4      Eternal Gandhi Super Series Crystal Paper Weig...
# ...                                                  ...
# 10133                                                NaN
# 10134                                                NaN
# 10135                                                NaN
# 10136                                                NaN
# 10137                                                NaN
#
#        flipkartretail_price  flipkartdiscounted_price  \
# 0                     999.0                     379.0
# 1                     999.0                     499.0
# 2                     699.0                     267.0
# 3                     220.0                     210.0
# 4                     430.0                     430.0
# ...                     ...                       ...
# 10133                   NaN                       NaN
# 10134                   NaN                       NaN
# 10135                   NaN                       NaN
# 10136                   NaN                       NaN
# 10137                   NaN                       NaN
#
#                                      flipkartdescription  \
# 0      Key Features of Alisha Solid Women's Cycling S...
# 1      Key Features of AW Bellies Sandals Wedges Heel...
# 2      Key Features of Alisha Solid Women's Cycling S...
# 3      Specifications of Sicons All Purpose Arnica Do...
# 4      Key Features of Eternal Gandhi Super Series Cr...
# ...                                                  ...
# 10133                                                NaN
# 10134                                                NaN
# 10135                                                NaN
# 10136                                                NaN
# 10137                                                NaN
#
#       flipkartoverall_rating   flipkartbrand  \
# 0        No rating available          Alisha
# 1        No rating available              AW
# 2        No rating available          Alisha
# 3        No rating available          Sicons
# 4        No rating available  Eternal Gandhi
# ...                      ...             ...
# 10133                    NaN             NaN
# 10134                    NaN             NaN
# 10135                    NaN             NaN
# 10136                    NaN             NaN
# 10137                    NaN             NaN
#
#                                       amazonproduct_name  amazonretail_price  \
# 0                    Alisha Solid Women's Cycling Shorts                 982
# 1                                             AW Bellies                 991
# 2                    Alisha Solid Women's Cycling Shorts                 694
# 3                  Sicons All Purpose Arnica Dog Shampoo                 208
# 4      Eternal Gandhi Super Series Crystal Paper Weig...                 427
# ...                                                  ...                 ...
# 10133                            JJC LH-DV37B  Lens Hood                  -2
# 10134                   Satzuma UCH100 USB Clapper Board                  -6
# 10135                         Satzuma USH102 USB USB Hub                  -1
# 10136               MUCHMORE ALLOY COPPER CHARM BRACELET                  -1
# 10137                                FRICTION MEN'S VEST                 -11
#
#        amazondiscounted_price  \
# 0                         438
# 1                         551
# 2                         325
# 3                         258
# 4                         473
# ...                       ...
# 10133                       0
# 10134                       0
# 10135                       0
# 10136                       0
# 10137                       0
#
#                                        amazondescription amazonoverall_rating  \
# 0      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1      Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 2      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 3      Specifications of Sicons All Purpose Arnica Do...  No rating available
# 4      Key Features of Eternal Gandhi Super Series Cr...  No rating available
# ...                                                  ...                  ...
# 10133  Buy JJC LH-DV37B  Lens Hood only for Rs. 0.0 f...  No rating available
# 10134  Buy Satzuma UCH100 USB Clapper Board for Rs.0 ...  No rating available
# 10135  Buy Satzuma USH102 USB USB Hub for Rs.0 online...  No rating available
# 10136  Muchmore Alloy Copper Charm Bracelet\n        ...  No rating available
# 10137  Key Features of FRICTION Men's Vest Graphic pr...  No rating available
#
#           amazonbrand
# 0              Alisha
# 1                  AW
# 2              Alisha
# 3              Sicons
# 4      Eternal Gandhi
# ...               ...
# 10133             JJC
# 10134         Satzuma
# 10135         Satzuma
# 10136        Muchmore
# 10137        FRICTION
#
# [10138 rows x 13 columns]

# %% [markdown]
# #### dropping unnecessary columns

# %%
cols_to_drop = ['flipkartoverall_rating','amazonoverall_rating', 'flipkartdescription', 'amazondescription',
       'flipkartbrand', 'amazonbrand']
df.drop(cols_to_drop, axis=1, inplace=True)
df.columns = ['uniq_id', 'flipkartproduct_name', 'flipkartretail_price','flipkartdiscounted_price', 'amazonproduct_name','amazonretail_price','amazondiscounted_price']

# %%
df
# Out:
#                                 uniq_id  \
# 0      c2d766ca982eca8304150849735ffef9
# 1      f449ec65dcbc041b6ae5e6a32717d01b
# 2      0973b37acd0c664e3de26e97e5571454
# 3      bc940ea42ee6bef5ac7cea3fb5cfbee7
# 4      c2a17313954882c1dba461863e98adf2
# ...                                 ...
# 10133  776ecca7b6f0584b1dffaeb4635b385a
# 10134  0fb87924d87d95d0a92b476c39fe6776
# 10135  a5590a2bfaddd4c4c9e9b6bf6409a464
# 10136  43fbafdae704714c6543690161d3adb1
# 10137  9d37d5a4ce327fb84cec4f56a2f0ac38
#
#                                     flipkartproduct_name  \
# 0                    Alisha Solid Women's Cycling Shorts
# 1                                             AW Bellies
# 2                    Alisha Solid Women's Cycling Shorts
# 3                  Sicons All Purpose Arnica Dog Shampoo
# 4      Eternal Gandhi Super Series Crystal Paper Weig...
# ...                                                  ...
# 10133                                                NaN
# 10134                                                NaN
# 10135                                                NaN
# 10136                                                NaN
# 10137                                                NaN
#
#        flipkartretail_price  flipkartdiscounted_price  \
# 0                     999.0                     379.0
# 1                     999.0                     499.0
# 2                     699.0                     267.0
# 3                     220.0                     210.0
# 4                     430.0                     430.0
# ...                     ...                       ...
# 10133                   NaN                       NaN
# 10134                   NaN                       NaN
# 10135                   NaN                       NaN
# 10136                   NaN                       NaN
# 10137                   NaN                       NaN
#
#                                       amazonproduct_name  amazonretail_price  \
# 0                    Alisha Solid Women's Cycling Shorts                 982
# 1                                             AW Bellies                 991
# 2                    Alisha Solid Women's Cycling Shorts                 694
# 3                  Sicons All Purpose Arnica Dog Shampoo                 208
# 4      Eternal Gandhi Super Series Crystal Paper Weig...                 427
# ...                                                  ...                 ...
# 10133                            JJC LH-DV37B  Lens Hood                  -2
# 10134                   Satzuma UCH100 USB Clapper Board                  -6
# 10135                         Satzuma USH102 USB USB Hub                  -1
# 10136               MUCHMORE ALLOY COPPER CHARM BRACELET                  -1
# 10137                                FRICTION MEN'S VEST                 -11
#
#        amazondiscounted_price
# 0                         438
# 1                         551
# 2                         325
# 3                         258
# 4                         473
# ...                       ...
# 10133                       0
# 10134                       0
# 10135                       0
# 10136                       0
# 10137                       0
#
# [10138 rows x 7 columns]

# %%
f_minus_a = df['amazondiscounted_price'] - df['flipkartdiscounted_price']
a_minus_f = df['amazondiscounted_price'] - df['flipkartdiscounted_price']

# %% [markdown]
# #### calculating the price differences between amazon and flipkart

# %%
df['price_diff'] = df['amazondiscounted_price'] - df['flipkartdiscounted_price']

# %%
df.price_diff.describe()
# Out:
# count    10073.000000
# mean        93.468579
# std         53.737971
# min          4.000000
# 25%         53.000000
# 50%         81.000000
# 75%        122.000000
# max        299.000000
# Name: price_diff, dtype: float64

# %%
df['price_diff_perc'] = df['price_diff']/df['amazondiscounted_price']*100
df
# Out:
#                                 uniq_id  \
# 0      c2d766ca982eca8304150849735ffef9
# 1      f449ec65dcbc041b6ae5e6a32717d01b
# 2      0973b37acd0c664e3de26e97e5571454
# 3      bc940ea42ee6bef5ac7cea3fb5cfbee7
# 4      c2a17313954882c1dba461863e98adf2
# ...                                 ...
# 10133  776ecca7b6f0584b1dffaeb4635b385a
# 10134  0fb87924d87d95d0a92b476c39fe6776
# 10135  a5590a2bfaddd4c4c9e9b6bf6409a464
# 10136  43fbafdae704714c6543690161d3adb1
# 10137  9d37d5a4ce327fb84cec4f56a2f0ac38
#
#                                     flipkartproduct_name  \
# 0                    Alisha Solid Women's Cycling Shorts
# 1                                             AW Bellies
# 2                    Alisha Solid Women's Cycling Shorts
# 3                  Sicons All Purpose Arnica Dog Shampoo
# 4      Eternal Gandhi Super Series Crystal Paper Weig...
# ...                                                  ...
# 10133                                                NaN
# 10134                                                NaN
# 10135                                                NaN
# 10136                                                NaN
# 10137                                                NaN
#
#        flipkartretail_price  flipkartdiscounted_price  \
# 0                     999.0                     379.0
# 1                     999.0                     499.0
# 2                     699.0                     267.0
# 3                     220.0                     210.0
# 4                     430.0                     430.0
# ...                     ...                       ...
# 10133                   NaN                       NaN
# 10134                   NaN                       NaN
# 10135                   NaN                       NaN
# 10136                   NaN                       NaN
# 10137                   NaN                       NaN
#
#                                       amazonproduct_name  amazonretail_price  \
# 0                    Alisha Solid Women's Cycling Shorts                 982
# 1                                             AW Bellies                 991
# 2                    Alisha Solid Women's Cycling Shorts                 694
# 3                  Sicons All Purpose Arnica Dog Shampoo                 208
# 4      Eternal Gandhi Super Series Crystal Paper Weig...                 427
# ...                                                  ...                 ...
# 10133                            JJC LH-DV37B  Lens Hood                  -2
# 10134                   Satzuma UCH100 USB Clapper Board                  -6
# 10135                         Satzuma USH102 USB USB Hub                  -1
# 10136               MUCHMORE ALLOY COPPER CHARM BRACELET                  -1
# 10137                                FRICTION MEN'S VEST                 -11
#
#        amazondiscounted_price  price_diff  price_diff_perc
# 0                         438        59.0        13.470320
# 1                         551        52.0         9.437387
# 2                         325        58.0        17.846154
# 3                         258        48.0        18.604651
# 4                         473        43.0         9.090909
# ...                       ...         ...              ...
# 10133                       0         NaN              NaN
# 10134                       0         NaN              NaN
# 10135                       0         NaN              NaN
# 10136                       0         NaN              NaN
# 10137                       0         NaN              NaN
#
# [10138 rows x 9 columns]

# %%
df.price_diff_perc.describe()
# Out:
# count    10073.000000
# mean        16.456519
# std          4.037494
# min          9.090909
# 25%         13.004484
# 50%         16.701461
# 75%         19.954128
# max         23.076923
# Name: price_diff_perc, dtype: float64

# %%
max_price = []
min_price = []
l = list()
for i, row in df.iterrows():
    if row['amazondiscounted_price'] < row['flipkartdiscounted_price']:
        max_price.append(row['flipkartdiscounted_price'])
        min_price.append(row['amazondiscounted_price'])
    else:
        max_price.append(row['amazondiscounted_price'])
        min_price.append(row['flipkartdiscounted_price'])

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(max_price, color='green')
sns.kdeplot(min_price, color='orange')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
plt.figure(figsize=(10, 6))
sns.distplot(abs(df['price_diff_perc']), kde=False, color='brown', bins=100)
plt.xlabel('Price Difference (Percentage)')
# Out:
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Price Difference (Percentage)')

# %%
no_diff = df[df['price_diff'] == 0].count()[0]/df.shape[0]
print('Percentage of products which are priced the same: {0:.2f}%'.format(no_diff*100))

print()
no_diff = df[(abs(df['price_diff_perc']) > 0) & (abs(df['price_diff_perc']) < 100)].count()[0]/df.shape[0]
print('Percentage of products with price difference: {0:.2f}%'.format(no_diff*100))

print()
no_diff = df[df['price_diff_perc'] < 0].count()[0]/df.shape[0]
print('Better pricing on Flipkart: {0:.2f}%'.format(no_diff*100))

print()
no_diff = df[df['price_diff_perc'] > 0].count()[0]/df.shape[0]
print('Better pricing on Amazon: {0:.2f}%'.format(no_diff*100))
# Out:
# Percentage of products which are priced the same: 0.00%
#
# Percentage of products with price difference: 99.36%
#
# Better pricing on Flipkart: 0.00%
#
# Better pricing on Amazon: 99.36%

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df['price_diff_perc'], kde=False, color='red')
plt.xlabel('Price Difference (Percentage)')
plt.ylabel('Products')
# Out:
# Text(0, 0.5, 'Products')

# %% [markdown]
# ## Thanks !!!
# #### END OF ASSIGNMENT
